# %%
import pandas as pd
import networkx as nx
from rapidfuzz import fuzz
import matplotlib.pyplot as plt
from pyvis.network import Network

# --- Step 1: Read CSV file ---
df = pd.read_csv('mdm_company_dataset_100.csv')

# %%
# --- Step 2: Define similarity scoring function ---
def similarity_score(rec1, rec2):
    name_score = fuzz.token_sort_ratio(str(rec1["party_name"]), str(rec2["party_name"]))
    city_score = fuzz.ratio(str(rec1["city"]), str(rec2["city"]))
    country_score = fuzz.ratio(str(rec1["country"]), str(rec2["country"]))

    # Weighted average (you can adjust weights)
    return (name_score * 0.8 + city_score * 0.1 + country_score * 0.1)

# %%
# --- Step 3: Build the similarity graph ---
G = nx.Graph()

# %%
# --- Add full metadata as node attributes ---
for _, row in df.iterrows():
    metadata = {
        "party_name": row["party_name"],
        "status": row["status"],
        "address_type": row["address_type"],
        "address_line1": row["address_line1"],
        "address_line2": row["address_line2"],
        "postcode": row["postcode"],
        "city": row["city"],
        "country": row["country"],
        "businessid_type": row["businessid_type"],
        "business_id_value": row["business_id_value"],
        "email": row["email"],
        "role": row["role"],
        "phone": row["phone"],
        "create_date": row["create_date"],
        "update_date": row["update_date"]
    }
    G.add_node(row["party_id"], **metadata)

# %%
# --- Compute pairwise similarities ---
threshold = 81
for i in range(len(df)):
    for j in range(i + 1, len(df)):
        score = similarity_score(df.iloc[i], df.iloc[j])
        if score >= threshold:
            G.add_edge(df.iloc[i]["party_id"], df.iloc[j]["party_id"], weight=score)

# --- Find clusters ---
clusters = list(nx.connected_components(G))
print(clusters)
# Out:
# [{'P001'}, {'P002'}, {'P003'}, {'P004', 'P005', 'P006'}, {'P008', 'P009', 'P007'}, {'P011', 'P010'}, {'P012', 'P013'}, {'P014', 'P015'}, {'P017', 'P016'}, {'P018', 'P019'}, {'P020', 'P021'}, {'P023', 'P022'}, {'P025', 'P024'}, {'P026', 'P027'}, {'P029', 'P028'}, {'P030', 'P031'}, {'P032', 'P033'}, {'P034', 'P035'}, {'P036', 'P037'}, {'P039', 'P038'}, {'P041', 'P040'}, {'P042', 'P043'}, {'P044', 'P045'}, {'P046', 'P047'}, {'P048', 'P049'}, {'P051', 'P050'}, {'P053', 'P052'}, {'P054', 'P055'}, {'P057', 'P056'}, {'P059', 'P058'}, {'P061', 'P060'}, {'P062', 'P063'}, {'P064', 'P065'}, {'P067', 'P066'}, {'P068'}, {'P069'}, {'P071', 'P070'}, {'P073', 'P072'}, {'P074'}, {'P075'}, {'P076', 'P077'}, {'P078', 'P079'}, {'P081', 'P080'}, {'P083', 'P082'}, {'P085', 'P084'}, {'P086', 'P087'}, {'P088', 'P089'}, {'P091', 'P090'}, {'P093', 'P092'}, {'P095', 'P094'}, {'P097', 'P096'}, {'P098', 'P099'}, {'P100'}]

# %%
# --- Print metadata for each cluster ---
for i, cluster in enumerate(clusters, 1):
    print(f"\n🔷 Cluster {i}:")
    for node in cluster:
        attrs = G.nodes[node]
        print(f" - {attrs['party_name']} ({attrs['city']}, {attrs['country']}) | VAT: {attrs['business_id_value']} | Role: {attrs['role']}")
# Out:
# 🔷 Cluster 1:
#  - Acme Corporation Ltd (New York, USA) | VAT: 12-3456789 | Role: Lessee
#
# 🔷 Cluster 2:
#  - ACME CORPORATION LIMITED (New York, USA) | VAT: 123456789 | Role: Lessee
#
# 🔷 Cluster 3:
#  - Acme Corp (New York, USA) | VAT: 12-3456789 | Role: Lessor
#
# 🔷 Cluster 4:
#  - Global Tech Industries Inc (San Francisco, USA) | VAT: 98-7654321 | Role: Lessee
#  - Global Tech Industries (San Francisco, USA) | VAT: 987654321 | Role: Lessee
#  - GlobalTech Industries Inc. (San Francisco, USA) | VAT: 98-7654321 | Role: Supplier
#
# 🔷 Cluster 5:
#  - Blue Ocean Logistics LLC (Los Angeles, USA) | VAT: 456789012 | Role: Lessee
#  - Bleu Ocean Logistics (Los Angeles, USA) | VAT: 45-6789012 | Role: Lessor
#  - Blue Ocean Logistics (Los Angeles, USA) | VAT: 45-6789012 | Role: Lessee
#
# 🔷 Cluster 6:
#  - TechStart Solutions Inc (Boston, USA) | VAT: 112233445 | Role: Lessee
#  - TechStart Solutions (Boston, USA) | VAT: 11-2233445 | Role: Lessee
#
# 🔷 Cluster 7:
#  - Sunrise Manufacturing Co (Chicago, USA) | VAT: 78-9012345 | Role: Supplier
#  - Sunrise Manufacturing Company (Chicago, USA) | VAT: 789012345 | Role: Supplier
#
# 🔷 Cluster 8:
#  - Quantum Innovations Ltd (Toronto, CAN) | VAT: 123456789RC0001 | Role: Lessee
#  - Quantum Innovations Limited (Toronto, CAN) | VAT: 123456789RC0001 | Role: Lessee
#
# 🔷 Cluster 9:
#  - Green Energy Solutions Inc (Phoenix, USA) | VAT: 334455667 | Role: Lessor
#  - Green Energy Solutions (Phoenix, USA) | VAT: 33-4455667 | Role: Lessor
#
# 🔷 Cluster 10:
#  - Metro Transport Services (Atlanta, USA) | VAT: 55-6677889 | Role: Lessee
#  - Metro Transportation Services (Atlanta, USA) | VAT: 556677889 | Role: Lessee
#
# 🔷 Cluster 11:
#  - Premier Financial Group (New York, USA) | VAT: 99-8877665 | Role: Lessor
#  - Premier Financial Group LLC (New York, USA) | VAT: 998877665 | Role: Lessor
#
# 🔷 Cluster 12:
#  - Diamond Retail Chains Inc (Dallas, USA) | VAT: 223344556 | Role: Lessee
#  - Diamond Retail Chain (Dallas, USA) | VAT: 22-3344556 | Role: Lessee
#
# 🔷 Cluster 13:
#  - Alpine Construction LLC (Denver, USA) | VAT: 445566778 | Role: Supplier
#  - Alpine Construction (Denver, USA) | VAT: 44-5566778 | Role: Supplier
#
# 🔷 Cluster 14:
#  - Coastal Shipping Ltd (Seattle, USA) | VAT: 66-7788990 | Role: Lessee
#  - Coastal Shipping Limited (Seattle, USA) | VAT: 667788990 | Role: Lessee
#
# 🔷 Cluster 15:
#  - Nexus Tech Partners Inc (Menlo Park, USA) | VAT: 889900112 | Role: Lessor
#  - Nexus Technology Partners (Menlo Park, USA) | VAT: 88-9900112 | Role: Lessor
#
# 🔷 Cluster 16:
#  - Urban Development Corp (Miami, USA) | VAT: 11-2244668 | Role: Lessee
#  - Urban Development Corporation (Miami, USA) | VAT: 112244668 | Role: Lessee
#
# 🔷 Cluster 17:
#  - Precision Medical Supplies (Philadelphia, USA) | VAT: 77-8899001 | Role: Supplier
#  - Precision Medical Supply Co (Philadelphia, USA) | VAT: 778899001 | Role: Supplier
#
# 🔷 Cluster 18:
#  - Stellar Communications Inc (Los Angeles, USA) | VAT: 33-5577991 | Role: Lessee
#  - Stellar Communications (Los Angeles, USA) | VAT: 335577991 | Role: Lessee
#
# 🔷 Cluster 19:
#  - Horizon Aerospace Ltd (Seattle, USA) | VAT: 99-0011223 | Role: Lessor
#  - Horizon Aerospace Limited (Seattle, USA) | VAT: 990011223 | Role: Lessor
#
# 🔷 Cluster 20:
#  - Velocity Automotive Group (Detroit, USA) | VAT: 446688002 | Role: Lessee
#  - Velocity Auto Group (Detroit, USA) | VAT: 44-6688002 | Role: Lessee
#
# 🔷 Cluster 21:
#  - Pacific Logistics Services Inc (San Diego, USA) | VAT: 557799113 | Role: Supplier
#  - Pacific Logistics Services (San Diego, USA) | VAT: 55-7799113 | Role: Supplier
#
# 🔷 Cluster 22:
#  - Evergreen Hospitality Group (Las Vegas, USA) | VAT: 66-8800224 | Role: Lessee
#  - Evergreen Hospitality Grp (Las Vegas, USA) | VAT: 668800224 | Role: Lessee
#
# 🔷 Cluster 23:
#  - Titan Manufacturing Industries (Cleveland, USA) | VAT: 77-9911335 | Role: Supplier
#  - Titan Manufacturing Ind (Cleveland, USA) | VAT: 779911335 | Role: Supplier
#
# 🔷 Cluster 24:
#  - Crown Property Management (Houston, USA) | VAT: 88-0022446 | Role: Lessor
#  - Crown Property Mgmt LLC (Houston, USA) | VAT: 880022446 | Role: Lessor
#
# 🔷 Cluster 25:
#  - Innovation Software Solutions (Austin, USA) | VAT: 99-1133557 | Role: Lessee
#  - Innovation Software Sol (Austin, USA) | VAT: 991133557 | Role: Lessee
#
# 🔷 Cluster 26:
#  - Atlantic Marine Services Inc (Boston, USA) | VAT: 113355779 | Role: Supplier
#  - Atlantic Marine Services (Boston, USA) | VAT: 11-3355779 | Role: Supplier
#
# 🔷 Cluster 27:
#  - Zenith Consulting Ptnrs (Washington, USA) | VAT: 224466880 | Role: Lessor
#  - Zenith Consulting Partners (Washington, USA) | VAT: 22-4466880 | Role: Lessor
#
# 🔷 Cluster 28:
#  - Redwood Furniture Co (Portland, USA) | VAT: 33-5577991 | Role: Supplier
#  - Redwood Furniture Company (Portland, USA) | VAT: 335577991 | Role: Supplier
#
# 🔷 Cluster 29:
#  - Summit Capital Partners LLC (San Francisco, USA) | VAT: 446688002 | Role: Lessor
#  - Summit Capital Partners (San Francisco, USA) | VAT: 44-6688002 | Role: Lessor
#
# 🔷 Cluster 30:
#  - Riverside Distribution Ctr (St Louis, USA) | VAT: 557799113 | Role: Lessee
#  - Riverside Distribution Center (St Louis, USA) | VAT: 55-7799113 | Role: Lessee
#
# 🔷 Cluster 31:
#  - Phoenix Marketing Grp Inc (Phoenix, USA) | VAT: 668800224 | Role: Supplier
#  - Phoenix Marketing Group (Phoenix, USA) | VAT: 66-8800224 | Role: Supplier
#
# 🔷 Cluster 32:
#  - Cascade Energy Systems (Seattle, USA) | VAT: 77-9911335 | Role: Lessee
#  - Cascade Energy Systems Inc (Seattle, USA) | VAT: 779911335 | Role: Lessee
#
# 🔷 Cluster 33:
#  - Liberty Insurance Group (New York, USA) | VAT: 88-0022446 | Role: Lessor
#  - Liberty Insurance Grp LLC (New York, USA) | VAT: 880022446 | Role: Lessor
#
# 🔷 Cluster 34:
#  - Granite Construction Svcs (Denver, USA) | VAT: 991133557 | Role: Supplier
#  - Granite Construction Services (Denver, USA) | VAT: 99-1133557 | Role: Supplier
#
# 🔷 Cluster 35:
#  - Mercury Telecommunications (Chicago, USA) | VAT: 11-3355779 | Role: Lessee
#
# 🔷 Cluster 36:
#  - Mercury Telecom Inc (Chicago, USA) | VAT: 113355779 | Role: Lessee
#
# 🔷 Cluster 37:
#  - Oakmont Real Estate Tr (Miami, USA) | VAT: 224466880 | Role: Lessor
#  - Oakmont Real Estate Trust (Miami, USA) | VAT: 22-4466880 | Role: Lessor
#
# 🔷 Cluster 38:
#  - Velocity Shipping Sol Inc (Atlanta, USA) | VAT: 335577991 | Role: Supplier
#  - Velocity Shipping Solutions (Atlanta, USA) | VAT: 33-5577991 | Role: Supplier
#
# 🔷 Cluster 39:
#  - Sapphire Technology Labs (Boston, USA) | VAT: 44-6688002 | Role: Lessee
#
# 🔷 Cluster 40:
#  - Sapphire Tech Laboratories (Boston, USA) | VAT: 446688002 | Role: Lessee
#
# 🔷 Cluster 41:
#  - Cornerstone Financial Services (New York, USA) | VAT: 55-7799113 | Role: Lessor
#  - Cornerstone Financial Svcs (New York, USA) | VAT: 557799113 | Role: Lessor
#
# 🔷 Cluster 42:
#  - Platinum Automotive Parts (Detroit, USA) | VAT: 66-8800224 | Role: Supplier
#  - Platinum Auto Parts Inc (Detroit, USA) | VAT: 668800224 | Role: Supplier
#
# 🔷 Cluster 43:
#  - Summit Logistics Intl (Los Angeles, USA) | VAT: 779911335 | Role: Lessee
#  - Summit Logistics International (Los Angeles, USA) | VAT: 77-9911335 | Role: Lessee
#
# 🔷 Cluster 44:
#  - Emerald Healthcare Sys (Philadelphia, USA) | VAT: 880022446 | Role: Lessee
#  - Emerald Healthcare Systems (Philadelphia, USA) | VAT: 88-0022446 | Role: Lessee
#
# 🔷 Cluster 45:
#  - Pinnacle Engineering Corporation (Austin, USA) | VAT: 991133557 | Role: Supplier
#  - Pinnacle Engineering Corp (Austin, USA) | VAT: 99-1133557 | Role: Supplier
#
# 🔷 Cluster 46:
#  - Harbor Freight Services (San Diego, USA) | VAT: 11-3355779 | Role: Lessee
#  - Harbor Freight Services LLC (San Diego, USA) | VAT: 113355779 | Role: Lessee
#
# 🔷 Cluster 47:
#  - Crimson Media Productions (Los Angeles, USA) | VAT: 22-4466880 | Role: Supplier
#  - Crimson Media Prod Inc (Los Angeles, USA) | VAT: 224466880 | Role: Supplier
#
# 🔷 Cluster 48:
#  - Westfield Development Grp (Dallas, USA) | VAT: 335577991 | Role: Lessor
#  - Westfield Development Group (Dallas, USA) | VAT: 33-5577991 | Role: Lessor
#
# 🔷 Cluster 49:
#  - Alpine Medical Equip Co (Phoenix, USA) | VAT: 446688002 | Role: Supplier
#  - Alpine Medical Equipment (Phoenix, USA) | VAT: 44-6688002 | Role: Supplier
#
# 🔷 Cluster 50:
#  - Riverside Tech Partners Inc (Menlo Park, USA) | VAT: 557799113 | Role: Lessee
#  - Riverside Technology Partners (Menlo Park, USA) | VAT: 55-7799113 | Role: Lessee
#
# 🔷 Cluster 51:
#  - Crown Transportation (Cleveland, USA) | VAT: 668800224 | Role: Lessee
#  - Crown Transportation LLC (Cleveland, USA) | VAT: 66-8800224 | Role: Lessee
#
# 🔷 Cluster 52:
#  - Northstar Consulting Group (Washington, USA) | VAT: 77-9911335 | Role: Lessor
#  - Northstar Consulting Grp (Washington, USA) | VAT: 779911335 | Role: Lessor
#
# 🔷 Cluster 53:
#  - Pacific Coast Manufacturing (Portland, USA) | VAT: 88-0022446 | Role: Supplier

# %%
# --- Create interactive Pyvis network ---
import re
net = Network(notebook=True,
              cdn_resources="remote",
              height="700px",
              width="100%",
              bgcolor="#222222",
              font_color="cyan",
              select_menu=True,
              filter_menu=True,

              )

# Load nodes with metadata into pyvis
for node, data in G.nodes(data=True):
    party_name = data.get('party_name', str(node))
    tooltip = f"""<html>
              <body>
              <div>
                <div style="font-weight: bold; font-size: 1.2em;">{data.get('party_name', '')}</div>
                <div class="info-row">Role: {data.get('role', '')}</div>
                <div class="info-row">VAT: {data.get('business_id_value', '')}</div>
                <div class="info-row">City: {data.get('city', '')}</div>
                <div class="info-row">Country: {data.get('country', '')}</div>
                <div class="info-row">Email: {data.get('email', '')}</div>
                <div class="info-row">Phone: {data.get('phone', '')}</div>
              </div>
              </body>
              </html>"""
    clean_tooltip = re.sub(r'<[^>]*>', '', tooltip)
    net.add_node(node, label=party_name, title=clean_tooltip,group=data.get('role'))



# Add edges with similarity weights
for u, v, d in G.edges(data=True):
    net.add_edge(u, v, value=d["weight"], title=f"Similarity: {d['weight']:.1f}")

net.show_buttons(filter_=['physics'])

net.write_html("party_similarity_network.html")

# %%
from google.colab import files
files.download("party_similarity_network.html")
